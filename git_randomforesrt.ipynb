# %% [markdown]
# <a href="https://colab.research.google.com/github/kannan-ux/sakthikannan--s/blob/main/git_randomforesrt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/customer_churn+(2).csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df['SeniorCitizen'].unique()
# Out:
# array([0, 1])

# %%
df['TotalCharges']=pd.to_numeric(df['TotalCharges'],errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
import seaborn as sns
for col in df.columns:
  if df[col].dtype=="object"and col!="SeniorCitizen":
    sns.boxplot(df[col])
    plt.xlabel(col)
    plt.show()

# %%
df.drop(['customerID'],axis=1,inplace=True)

# %%
df
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for col in df.columns:
  if df[col].dtype=="object":
    df[col]=le.fit_transform(df[col])

# %%
df
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
X=df.drop(['Churn'],axis=1)

# %%
Y=df['Churn']

# %%
X
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0          0              0        1           0       1             0
# 1          1              0        0           0      34             1
# 2          1              0        0           0       2             1
# 3          1              0        0           0      45             0
# 4          0              0        0           0       2             1
# ...      ...            ...      ...         ...     ...           ...
# 7038       1              0        1           1      24             1
# 7039       0              0        1           1      72             1
# 7040       0              0        1           1      11             0
# 7041       1              1        1           0       4             1
# 7042       1              0        0           0      66             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
Y
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=3)

# %%
X_train
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5993       1              0        0           0       2             1
# 6405       0              1        0           0      60             1
# 3683       1              0        1           0      71             1
# 7011       0              0        0           0       4             1
# 4114       0              0        1           1      51             1
# ...      ...            ...      ...         ...     ...           ...
# 971        1              0        1           0      49             1
# 1672       1              0        1           1      72             1
# 3326       1              1        0           0      38             1
# 1693       1              0        1           0      72             1
# 6003       0              0        1           0      71             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
X_test
# Out:
#       gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 5580       1              0        0           0      48             1
# 3438       1              0        1           0      18             1
# 2175       0              0        0           0      30             1
# 4237       1              0        0           0       5             1
# 511        1              0        0           0      61             1
# ...      ...            ...      ...         ...     ...           ...
# 732        1              0        1           1      25             1
# 3858       1              0        0           0      47             1
# 3320       1              1        1           0      18             1
# 4819       1              0        0           1      53             1
# 5403       0              0        1           1      54             1
#
#       MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import*

# %%
rlf=RandomForestClassifier(n_estimators=50,random_state=20)

# %%
rlf
# Out:
# RandomForestClassifier(n_estimators=50, random_state=20)

# %%
rlf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=20)

# %%
y_pred=rlf.predict(X_test)

# %%
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.7945984363894811

# %%
rlf.score(X_test,Y_test)
# Out:
# 0.7945984363894811

# %%
y_pred1=rlf.predict(X_train)

# %%
accuracy_score(Y_train,y_pred1)
# Out:
# 0.9969777777777777

# %%
rlf.score(X_train,Y_train)
# Out:
# 0.9969777777777777

# %%
cm=confusion_matrix(Y_test,y_pred)

# %%
cm
# Out:
# array([[952,  99],
#        [190, 166]])

# %%
  print(classification_report(Y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      1051
#            1       0.63      0.47      0.53       356
#
#     accuracy                           0.79      1407
#    macro avg       0.73      0.69      0.70      1407
# weighted avg       0.78      0.79      0.78      1407

# %%
sns.heatmap(cm,annot=True,cmap="Greens",fmt="d")
# Out:
# <Axes: >

# %%
n=[100,150,200,250,300,350,400,450,500,550,600,650,700]

# %%
for X in n:
  model=RandomForestClassifier(n_estimators=X,random_state=20)
  model.fit(X_train,Y_train)
  pred=model.predict(X_test)
  acc=accuracy_score(Y_test,pred)*100
  print("no.of.trees=",X,"accuracy=",acc)
# Out:
# no.of.trees= 100 accuracy= 79.38877043354655
# no.of.trees= 150 accuracy= 79.67306325515281
# no.of.trees= 200 accuracy= 79.45984363894812
# no.of.trees= 250 accuracy= 79.1044776119403
# no.of.trees= 300 accuracy= 79.317697228145
# no.of.trees= 350 accuracy= 79.17555081734187
# no.of.trees= 400 accuracy= 79.53091684434968
# no.of.trees= 450 accuracy= 79.1044776119403
# no.of.trees= 500 accuracy= 79.24662402274343
# no.of.trees= 550 accuracy= 78.96233120113718
# no.of.trees= 600 accuracy= 78.89125799573561
# no.of.trees= 650 accuracy= 78.89125799573561
# no.of.trees= 700 accuracy= 79.03340440653874

# %%
param_grid={
    "n_estimators":[100,200,300],
    "max_depth":[None,5,10],
    "min_samples_split":[2,5,10],
    "min_samples_leaf":[1,2,4],
    "criterion":["gini","entropy"]

}

# %%
from sklearn.ensemble  import  RandomForestClassifier

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier2=RandomForestClassifier(random_state=23)

# %%
grid_search=GridSearchCV(estimator=classifier2 ,   param_grid=param_grid  ,cv=2)

# %%
grid_search.fit(X_train,Y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(random_state=23),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 5, 10],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300]})

# %%
print(grid_search.best_params_)
# Out:
# {'criterion': 'entropy', 'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 300}

# %%
new_model=RandomForestClassifier(criterion= 'entropy', max_depth= 5, min_samples_leaf= 1, min_samples_split= 10, n_estimators= 300)

# %%
new_model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, min_samples_split=10,
#                        n_estimators=300)

# %%
new_pred=new_model.predict(X_test)

# %%
accuracy_score(Y_test,new_pred)
# Out:
# 0.8073916133617626

# %%
print(classification_report(Y_test,new_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.92      0.88      1051
#            1       0.67      0.47      0.55       356
#
#     accuracy                           0.81      1407
#    macro avg       0.75      0.70      0.71      1407
# weighted avg       0.79      0.81      0.80      1407

# %%
cx=[0,0,1,1,30,0,2,2,0,1,0,2,0,1,2,1,3,40.0,300.90]

# %%
new_model.predict([cx])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
# array([0])

# %%
# the model predicted  the customer is not churn
