# %%
 import pandas as pd
 import numpy as np
 import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/new_insurance_data.csv")
df
# Out:
#        age     sex     bmi  children smoker  Claim_Amount  past_consultations  \
# 0     18.0    male  23.210       0.0     no   29087.54313                17.0
# 1     18.0    male  30.140       0.0     no   39053.67437                 7.0
# 2     18.0    male  33.330       0.0     no   39023.62759                19.0
# 3     18.0    male  33.660       0.0     no   28185.39332                11.0
# 4     18.0    male  34.100       0.0     no   14697.85941                16.0
# ...    ...     ...     ...       ...    ...           ...                 ...
# 1333  33.0  female  35.530       0.0    yes   63142.25346                32.0
# 1334  31.0  female  38.095       1.0    yes   43419.95227                31.0
# 1335  52.0    male  34.485       3.0    yes   52458.92353                25.0
# 1336  45.0    male  30.360       0.0    yes   69927.51664                34.0
# 1337  54.0  female  47.410       0.0    yes   63982.80926                31.0
#
#       num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0         715428.0          4.720921e+06                              0.0
# 1         699157.0          4.329832e+06                              0.0
# 2         702341.0          6.884861e+06                              0.0
# 3         700250.0          4.274774e+06                              0.0
# 4         711584.0          3.787294e+06                              0.0
# ...            ...                   ...                              ...
# 1333     1091267.0          1.703805e+08                              2.0
# 1334     1107872.0          2.015152e+08                              2.0
# 1335     1092005.0          2.236450e+08                              2.0
# 1336     1106821.0          2.528924e+08                              3.0
# 1337     1100328.0          2.616317e+08                              3.0
#
#       Anual_Salary     region      charges
# 0     5.578497e+07  southeast   1121.87390
# 1     1.370089e+07  southeast   1131.50660
# 2     7.352311e+07  southeast   1135.94070
# 3     7.581968e+07  southeast   1136.39940
# 4     2.301232e+07  southeast   1137.01100
# ...            ...        ...          ...
# 1333  3.101107e+09  northwest  55135.40209
# 1334  3.484216e+09  northeast  58571.07448
# 1335  3.640807e+09  northwest  60021.39897
# 1336  4.006359e+09  southeast  62592.87309
# 1337  4.117197e+09  southeast  63770.42801
#
# [1338 rows x 13 columns]

# %%
df.head()
# Out:
#     age   sex    bmi  children smoker  Claim_Amount  past_consultations  \
# 0  18.0  male  23.21       0.0     no   29087.54313                17.0
# 1  18.0  male  30.14       0.0     no   39053.67437                 7.0
# 2  18.0  male  33.33       0.0     no   39023.62759                19.0
# 3  18.0  male  33.66       0.0     no   28185.39332                11.0
# 4  18.0  male  34.10       0.0     no   14697.85941                16.0
#
#    num_of_steps  Hospital_expenditure  NUmber_of_past_hospitalizations  \
# 0      715428.0           4720920.992                              0.0
# 1      699157.0           4329831.676                              0.0
# 2      702341.0           6884860.774                              0.0
# 3      700250.0           4274773.550                              0.0
# 4      711584.0           3787293.921                              0.0
#
#    Anual_Salary     region    charges
# 0   55784970.05  southeast  1121.8739
# 1   13700885.19  southeast  1131.5066
# 2   73523107.27  southeast  1135.9407
# 3   75819679.60  southeast  1136.3994
# 4   23012320.01  southeast  1137.0110

# %%
df.shape
# Out:
# (1338, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 13 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   age                              1329 non-null   float64
#  1   sex                              1338 non-null   object
#  2   bmi                              1335 non-null   float64
#  3   children                         1333 non-null   float64
#  4   smoker                           1338 non-null   object
#  5   Claim_Amount                     1324 non-null   float64
#  6   past_consultations               1332 non-null   float64
#  7   num_of_steps                     1335 non-null   float64
#  8   Hospital_expenditure             1334 non-null   float64
#  9   NUmber_of_past_hospitalizations  1336 non-null   float64
#  10  Anual_Salary                     1332 non-null   float64
#  11  region                           1338 non-null   object
#  12  charges                          1338 non-null   float64
# dtypes: float64(10), object(3)
# memory usage: 136.0+ KB

# %%
df.isnull().sum()
# Out:
# age                                 9
# sex                                 0
# bmi                                 3
# children                            5
# smoker                              0
# Claim_Amount                       14
# past_consultations                  6
# num_of_steps                        3
# Hospital_expenditure                4
# NUmber_of_past_hospitalizations     2
# Anual_Salary                        6
# region                              0
# charges                             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
col_list=list(df)
col_list
# Out:
# ['age',
#  'sex',
#  'bmi',
#  'children',
#  'smoker',
#  'Claim_Amount',
#  'past_consultations',
#  'num_of_steps',
#  'Hospital_expenditure',
#  'NUmber_of_past_hospitalizations',
#  'Anual_Salary',
#  'region',
#  'charges']

# %%
df['smoker'].mode()
# Out:
# 0    no
# Name: smoker, dtype: object

# %%
df['smoker'].mode()[0]
# Out:
# 'no'

# %%
for i in col_list:
  if df[i].dtype=="object":
   df[i]=df[i].fillna(df[i].mode()[0])
  else:
   df[i]=df[i].fillna(df[i].mean())

# %%
df.isnull().sum()
# Out:
# age                                0
# sex                                0
# bmi                                0
# children                           0
# smoker                             0
# Claim_Amount                       0
# past_consultations                 0
# num_of_steps                       0
# Hospital_expenditure               0
# NUmber_of_past_hospitalizations    0
# Anual_Salary                       0
# region                             0
# charges                            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in col_list:
  if ((df[i].dtype=="int64")or(df[i].dtype=="float64")):
   plt.hist(df[i])
   plt.xlabel(i)
   plt.ylabel("count")
   plt.show()

# %%
import  seaborn as sns
for i in col_list:
  if ((df[i].dtype=='int64')or(df[i].dtype=='float64')):
     sns.boxplot(df[i])
     plt.xlabel(i)
     plt.ylabel("count")
     plt.show()

# %%
out_list=['bmi','past_consultations','Anual_Salary','Hospital_expenditure']

# %%
for i in out_list:
   Q1=df[i].quantile(0.25)
   Q3=df[i].quantile(0.75)
   IQR=Q3-Q1
   df=df[(df[i]>Q1-1.5*IQR)&(df[i]<Q3+1.5*IQR)]
   df

# %%
df.shape
# Out:
# (1110, 13)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
col_list=[]
for i  in  df.columns:
  if ((df[i].dtype != "object") &(i!='charges')) :
    col_list.append(i)
X=df[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#                            feature        VIF
# 0                              age  13.756871
# 1                              bmi  26.453884
# 2                         children   2.018874
# 3                     Claim_Amount   5.866154
# 4               past_consultations   6.633502
# 5                     num_of_steps  61.788813
# 6             Hospital_expenditure   6.378002
# 7  NUmber_of_past_hospitalizations  12.122300
# 8                     Anual_Salary   4.921670

# %%
df=df.drop(['num_of_steps'],axis=1)

# %%
col_list=[]
for  i in df.columns:
   if((df[i].dtype != 'object')&(i!='charges')):
    col_list.append(i)
X=df[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i)for i in range(len(X.columns))]
vif_data
# Out:
#                            feature        VIF
# 0                              age  12.424698
# 1                              bmi  12.357258
# 2                         children   1.996548
# 3                     Claim_Amount   5.419443
# 4               past_consultations   6.198033
# 5             Hospital_expenditure   6.088201
# 6  NUmber_of_past_hospitalizations  10.995568
# 7                     Anual_Salary   4.879047

# %%
df=df.drop(['age'],axis=1)

# %%
col_list=[]
for i in df.columns:
  if((df[i].dtype!='object')&(i!='charges')):
    col_list.append(i)
X=df[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns)) ]
vif_data
# Out:
#                            feature       VIF
# 0                              bmi  9.917506
# 1                         children  1.966246
# 2                     Claim_Amount  5.395143
# 3               past_consultations  6.152450
# 4             Hospital_expenditure  6.074152
# 5  NUmber_of_past_hospitalizations  8.570438
# 6                     Anual_Salary  4.805638

# %%
df=df.drop(['bmi'],axis=1)

# %%
col_list=[]
for i in df.columns:
  if((df[i].dtype!='object')&(i!='charges')):
    col_list.append(i)
X=df[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns)) ]
vif_data
# Out:
#                            feature       VIF
# 0                         children  1.963521
# 1                     Claim_Amount  4.614920
# 2               past_consultations  5.238547
# 3             Hospital_expenditure  5.598843
# 4  NUmber_of_past_hospitalizations  7.217113
# 5                     Anual_Salary  4.399817

# %%
df=df.drop(['NUmber_of_past_hospitalizations'],axis=1)

# %%
col_list=[]
for i in df.columns:
  if((df[i].dtype!='object')&(i!='charges')):
    col_list.append(i)
X=df[col_list]
vif_data=pd.DataFrame()
vif_data['feature']=X.columns
vif_data['VIF']=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]
vif_data
# Out:
#                 feature       VIF
# 0              children  1.707996
# 1          Claim_Amount  4.065000
# 2    past_consultations  4.779687
# 3  Hospital_expenditure  5.405033
# 4          Anual_Salary  4.202299

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
 X
# Out:
#       children  Claim_Amount  past_consultations  Hospital_expenditure  \
# 0          0.0   29087.54313                17.0          4.720921e+06
# 1          0.0   39053.67437                 7.0          4.329832e+06
# 2          0.0   39023.62759                19.0          6.884861e+06
# 3          0.0   28185.39332                11.0          4.274774e+06
# 4          0.0   14697.85941                16.0          3.787294e+06
# ...        ...           ...                 ...                   ...
# 1126       0.0   37385.45533                26.0          1.579127e+07
# 1127       0.0   22174.08804                13.0          1.741167e+07
# 1129       2.0   46731.42714                26.0          1.762967e+07
# 1133       3.0   40405.58219                22.0          1.695495e+07
# 1140       3.0   45956.96538                19.0          1.709004e+07
#
#       Anual_Salary
# 0     5.578497e+07
# 1     1.370089e+07
# 2     7.352311e+07
# 3     7.581968e+07
# 4     2.301232e+07
# ...            ...
# 1126  6.863093e+08
# 1127  6.648504e+08
# 1129  6.041507e+08
# 1133  6.549545e+08
# 1140  6.461079e+08
#
# [1110 rows x 5 columns]

# %%
Y=df.iloc[:,-1]
Y
# Out:
# 0        1121.87390
# 1        1131.50660
# 2        1135.94070
# 3        1136.39940
# 4        1137.01100
#            ...
# 1126    24476.47851
# 1127    24513.09126
# 1129    24535.69855
# 1133    24869.83680
# 1140    25382.29700
# Name: charges, Length: 1110, dtype: float64

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2, random_state=999)

# %%
X_train
# Out:
#       children  Claim_Amount  past_consultations  Hospital_expenditure  \
# 1093       1.0  25609.160980                17.0          1.526045e+07
# 956        0.0  19734.029990                16.0          6.339239e+06
# 712        2.0  48984.901030                14.0          5.827840e+06
# 988        3.0  34311.811140                25.0          8.430907e+06
# 967        1.0  18589.969880                 8.0          1.204561e+07
# ...        ...           ...                 ...                   ...
# 477        2.0  30943.342060                17.0          2.941387e+06
# 227        1.0  16091.000090                11.0          3.454417e+06
# 483        2.0  18512.993280                16.0          7.442466e+05
# 875        0.0  41844.564980                 8.0          1.191697e+07
# 350        2.0   5754.536415                14.0          2.135526e+06
#
#       Anual_Salary
# 1093  5.343260e+08
# 956   2.499716e+08
# 712   1.262329e+08
# 988   3.280802e+08
# 967   2.388070e+08
# ...            ...
# 477   6.400286e+07
# 227   7.257541e+07
# 483   1.368503e+08
# 875   1.629471e+08
# 350   1.064679e+08
#
# [888 rows x 5 columns]

# %%
Y_train
# Out:
# 1093    21771.34230
# 956     14254.60820
# 712     10043.24900
# 988     15612.19335
# 967     14418.28040
#            ...
# 477      6640.54485
# 227      3471.40960
# 483      6710.19190
# 875     12523.60480
# 350      4889.99950
# Name: charges, Length: 888, dtype: float64

# %%
model=LinearRegression()
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import *
r2=r2_score(Y_test,y_pred)

# %%
r2
# Out:
# 0.8637620601318555

# %%
X_test
# Out:
#       children  Claim_Amount  past_consultations  Hospital_expenditure  \
# 216        1.0  13041.904830                 4.0          1.273883e+06
# 376        3.0   4203.109713                20.0          7.268860e+06
# 353        5.0  33361.327180                21.0          9.418857e+06
# 949        3.0  43412.291820                10.0          7.131182e+06
# 908        1.0  32559.210650                 9.0          1.193068e+07
# ...        ...           ...                 ...                   ...
# 1082       2.0  30374.034720                11.0          1.379672e+07
# 866        1.0  22670.053110                20.0          6.133821e+06
# 438        3.0  28578.499090                18.0          8.616323e+06
# 993        3.0  20212.558840                16.0          4.530674e+06
# 992        2.0  14275.460420                17.0          9.213098e+06
#
#       Anual_Salary
# 216   3.933610e+07
# 376   9.767320e+07
# 353   6.188455e+07
# 949   2.908563e+08
# 908   2.610378e+08
# ...            ...
# 1082  4.769480e+08
# 866   1.670188e+08
# 438   6.663892e+07
# 993   2.787266e+08
# 992   2.906476e+08
#
# [222 rows x 5 columns]

# %%
model.predict([[1.0	,13041.904830	,4.0,	1.273883e+06,	3.933610e+07]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3477.84134547])
